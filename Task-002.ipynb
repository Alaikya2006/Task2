# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
sns.set(style="whitegrid")

# %%
df = pd.read_csv("C:/Users/joshi/Downloads/netflix_titles.csv")

# %%
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None

# %%
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='type', hue='type', palette='Set2', legend=False)
plt.title('Number of Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
top_countries = df['country'].value_counts().head(10)
country_df = top_countries.reset_index()
country_df.columns = ['country', 'count']
sns.barplot(data=country_df, x='count', y='country', hue='country', palette='Set3', legend=False)
plt.title('Top 10 Countries with the Most Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(12,5))
df['release_year'].value_counts().sort_index(ascending=False).head(20).plot(kind='bar', color='skyblue')
plt.title('Content Release Year Distribution (Top 20 Years)')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %%
from collections import Counter

genre_counts = Counter()
df['listed_in'].dropna().apply(lambda x: genre_counts.update(x.split(', ')))
top_genres = genre_counts.most_common(10)

# %%
import pandas as pd

genre_df = pd.DataFrame({
    'genre': genres,
    'count': counts
})

plt.figure(figsize=(10, 5))
sns.barplot(data=genre_df, x='count', y='genre', hue='genre', palette='coolwarm', legend=False)
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()
